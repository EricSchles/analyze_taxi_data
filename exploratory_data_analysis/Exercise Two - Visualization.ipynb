# %% [markdown]
# # Exploratory Data Analysis - Visualizing Data
#
# Below we will see how to visualize data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Visualization In Python
#
# Data Visualization is fairly straight forward in the matplotlib simply provide the values of interest

# %%
random_data = pd.read_csv("random_data.csv")

plt.ylabel("Column A")
plt.plot(range(len(random_data)), random_data["A"])
plt.show()
